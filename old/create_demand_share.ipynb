# %% [markdown]
# This file creat the "quantity" parameters for the agents.csv file (in MUSE).

# %%
import pandas as pd
from pathlib import Path
import numpy as np

from sklearn.linear_model import LinearRegression

# %%
#### Ofgem_Archetype data folder
data_folder = Path.cwd().parent / "Ofgem_Archetype"

#output folder
output_folder = Path.cwd().parent / "Residential"/ "MUSE_files"/ "Ofgem_agents"

# read the tables in the excel file
df = pd.read_excel(data_folder / "Ofgem energy consumer archetypes2024_Tables1.xlsx",sheet_name="original").dropna()

# display the data
df.head()
# Out:
#   Archetype  Number of\nhouseholds  Average Annual Elec consumption (kWh)  \
# 0        A1                 578333                                   2742
# 1        A2                 868191                                   2849
# 2        A3                 883413                                   3519
# 3        B4                 731318                                   4811
# 4        B5                 465288                                   6597
#
#    Average Annual Gas consumption (kWh)                   Main heating Fuel  \
# 0                                 10933                           Mains gas
# 1                                  9464                           Mains gas
# 2                                 10622                           Mains gas
# 3                                     0                         Electricity
# 4                                     0  Electricity/Other (Solid fuel/LPG)
#
#    Gross annual household income  \
# 0                          15643
# 1                          17327
# 2                          18195
# 3                          18776
# 4                          22423
#
#                               Attributes (key words)
# 0  Lowest income; mains gas; retired; 75+ years o...
# 1  Low income; housing association; single adults...
# 2  Low income; mains gas; retired/unoccupied < 65...
# 3  Low income; electric heating; retired/unoccupi...
# 4  Low income; electric/solid fuel/LPG heating; 4...

# %% [markdown]
# ### Predict the consumption (kwh) of Archetypes that use Oil/Other/Solid fuel/LPG as main heating fuels

# %%
# Filter rows where 'Main heating Fuel' is 'Mains gas' and drop rows with NaN in the required columns
filtered_df = df[df['Main heating Fuel'] == 'Mains gas'].dropna(
    subset=['Average Annual Elec consumption (kWh)', 'Average Annual Gas consumption (kWh)']
)

# Prepare the data for linear regression
X = filtered_df[['Average Annual Elec consumption (kWh)']]  # Keep feature names as DataFrame
y = filtered_df['Average Annual Gas consumption (kWh)'].values  # Target as array

# Create and train the linear regression model
model = LinearRegression()
model.fit(X, y)

# Filter rows where 'Main heating Fuel' is NOT 'Mains gas', 'Electricity', or 'Electricity/Other (Solid fuel/LPG)'
non_main_fuel_rows = df[
    ~df['Main heating Fuel'].isin(['Mains gas', 'Electricity', 'Electricity/Other (Solid fuel/LPG)'])
].copy()  # Create a copy to avoid SettingWithCopyWarning

# Predict the 'Average Annual consumption (kWh)' for these rows
non_main_fuel_rows['Predicted Consumption (kWh)'] = model.predict(
    non_main_fuel_rows[['Average Annual Elec consumption (kWh)']]
)

# %%
non_main_fuel_rows
# Out:
#    Archetype  Number of\nhouseholds  Average Annual Elec consumption (kWh)  \
# 14       F15                 323433                                   6883
# 16       G17                 163166                                   5901
# 17       G18                 667836                                   5294
# 18       H19                 675712                                   4907
# 23       J24                 231658                                   7523
#
#     Average Annual Gas consumption (kWh)           Main heating Fuel  \
# 14                                     0           Other/Electricity
# 16                                     0  Oil/Other (solid fuel/LPG)
# 17                                     0      Other (solid fuel/LPG)
# 18                                     0                         Oil
# 23                                     0                         Oil
#
#     Gross annual household income  \
# 14                          46005
# 16                          44586
# 17                          49265
# 18                          52621
# 23                          78813
#
#                                Attributes (key words)  \
# 14  Middle income; other/electric heating fuel; 2+...
# 16  Upper middle income; Oil/Other heating system;...
# 17  Upper middle income; Other heating fuel; owner...
# 18  Upper-middle income; oil heating fuel; retired...
# 23  Highest earners; 1+ children; oil heating; hig...
#
#     Predicted Consumption (kWh)
# 14                 24946.730237
# 16                 21410.232219
# 17                 19224.229880
# 18                 17830.518340
# 23                 27251.576195

# %%
# Add the 'Predicted Consumption (kWh)' column to the original DataFrame (set to NaN for rows not in non_main_fuel_rows)
df['Predicted Consumption (kWh)'] = np.nan
df.loc[non_main_fuel_rows.index, 'Predicted Consumption (kWh)'] = non_main_fuel_rows['Predicted Consumption (kWh)']

# %%
# Calculate 'demand_share'
df['demand_share'] = np.where(
    df['Predicted Consumption (kWh)'].notna(),  # If there is a predicted value
    df['Predicted Consumption (kWh)'] + df['Average Annual Elec consumption (kWh)'],  # Use predicted value
    df['Average Annual Gas consumption (kWh)'] + df['Average Annual Elec consumption (kWh)']  # Use actual value
)

# %%
# Calculate the sum of the 'demand_share' column (will be used as "demand_share" in the Agent.csv file)
total_consumption_sum = df['demand_share'].sum()

# Add a new column 'demand_share'
df['demand_share'] = df['demand_share'] / total_consumption_sum

# display the df
df
# Out:
#    Archetype  Number of\nhouseholds  Average Annual Elec consumption (kWh)  \
# 0         A1                 578333                                   2742
# 1         A2                 868191                                   2849
# 2         A3                 883413                                   3519
# 3         B4                 731318                                   4811
# 4         B5                 465288                                   6597
# 5         B6                 920172                                   3028
# 6         C7                 659595                                   3649
# 7         C8                 228477                                   5587
# 8         C9                3408514                                   3337
# 9        D10                1163946                                   3881
# 10       D11                1197075                                   2482
# 11       D12                1457829                                   3952
# 12       E13                 690892                                   5075
# 13       E14                1178684                                   4070
# 14       F15                 323433                                   6883
# 15       F16                 989639                                   4317
# 16       G17                 163166                                   5901
# 17       G18                 667836                                   5294
# 18       H19                 675712                                   4907
# 19       H20                3540270                                   3143
# 20       I21                2210494                                   4070
# 21       I22                1792593                                   4684
# 22       J23                1956103                                   4532
# 23       J24                 231658                                   7523
#
#     Average Annual Gas consumption (kWh)                   Main heating Fuel  \
# 0                                  10933                           Mains gas
# 1                                   9464                           Mains gas
# 2                                  10622                           Mains gas
# 3                                      0                         Electricity
# 4                                      0  Electricity/Other (Solid fuel/LPG)
# 5                                  10525                           Mains gas
# 6                                  13119                           Mains gas
# 7                                      0                         Electricity
# 8                                  13685                           Mains gas
# 9                                  13981                           Mains gas
# 10                                  8782                           Mains gas
# 11                                 16065                           Mains gas
# 12                                 16722                           Mains gas
# 13                                 14606                           Mains gas
# 14                                     0                   Other/Electricity
# 15                                     0                         Electricity
# 16                                     0          Oil/Other (solid fuel/LPG)
# 17                                     0              Other (solid fuel/LPG)
# 18                                     0                                 Oil
# 19                                 11677                           Mains gas
# 20                                 15461                           Mains gas
# 21                                 18530                           Mains gas
# 22                                 16330                           Mains gas
# 23                                     0                                 Oil
#
#     Gross annual household income  \
# 0                           15643
# 1                           17327
# 2                           18195
# 3                           18776
# 4                           22423
# 5                           24869
# 6                           29257
# 7                           32240
# 8                           32344
# 9                           31819
# 10                          40980
# 11                          38927
# 12                          38351
# 13                          43026
# 14                          46005
# 15                          50721
# 16                          44586
# 17                          49265
# 18                          52621
# 19                          58924
# 20                          59668
# 21                          68332
# 22                          74795
# 23                          78813
#
#                                Attributes (key words)  \
# 0   Lowest income; mains gas; retired; 75+ years o...
# 1   Low income; housing association; single adults...
# 2   Low income; mains gas; retired/unoccupied < 65...
# 3   Low income; electric heating; retired/unoccupi...
# 4   Low income; electric/solid fuel/LPG heating; 4...
# 5   Low income; mains gas; private rented/local au...
# 6   Lower-middle income; mains gas; purpose-built ...
# 7   Lower middle-income; electric heating; purpose...
# 8   Lower-middle income; couples/single adult woma...
# 9   Lower-middle income; mains gas; disability ben...
# 10  Lower-middle income; low energy consumption; g...
# 11  Lower-middle income; retired 65+; owner occupi...
# 12  Middle income; <35-54 year old unoccupied/reti...
# 13  Middle income earners; 2+ children; 25-54 year...
# 14  Middle income; other/electric heating fuel; 2+...
# 15  Middle income; electric heating; has degree or...
# 16  Upper middle income; Oil/Other heating system;...
# 17  Upper middle income; Other heating fuel; owner...
# 18  Upper-middle income; oil heating fuel; retired...
# 19  Upper-middle income; mains gas; early adopters...
# 20  High income; mains gas; 1 child; full-time emp...
# 21  High income; no children; mains gas; highest g...
# 22  High income; mains gas; 2+ children; 35-54 yea...
# 23  Highest earners; 1+ children; oil heating; hig...
#
#     Predicted Consumption (kWh)  demand_share
# 0                           NaN      0.032715
# 1                           NaN      0.029457
# 2                           NaN      0.033830
# 3                           NaN      0.011510
# 4                           NaN      0.015782
# 5                           NaN      0.032424
# 6                           NaN      0.040115
# 7                           NaN      0.013366
# 8                           NaN      0.040723
# 9                           NaN      0.042732
# 10                          NaN      0.026947
# 11                          NaN      0.047888
# 12                          NaN      0.052146
# 13                          NaN      0.044680
# 14                 24946.730237      0.076148
# 15                          NaN      0.010328
# 16                 21410.232219      0.065338
# 17                 19224.229880      0.058656
# 18                 17830.518340      0.054396
# 19                          NaN      0.035455
# 20                          NaN      0.046725
# 21                          NaN      0.055536
# 22                          NaN      0.049909
# 23                 27251.576195      0.083193

# %% [markdown]
# ## Create the Agent class and create Agent.csv for MUSE input

# %%
# define the Agent class
class Agent:
    """
    Represents an agent with various attributes and methods.
    Attributes:
        Name (str): The name of the agent.
        AgentShare (float): The share of the agent.
        RegionName (str): The name of the region.
        Objective1 (str): The first objective of the agent.
        Objective2 (str): The second objective of the agent.
        Objective3 (str): The third objective of the agent.
        ObjData1 (float): A weight associated with the first objective
        ObjData2 (float): A weight associated with the second objective.
        ObjData3 (float): A weight associated with the third objective.
        Objsort1 (Boolean): Sets whether first objective is maximized or minimized. For both “adhoc” and “scipy” solvers this should be set to “True” for minimization and “False” for maximisation.
        Objsort2 (Boolean): The sorting criteria for the second objective.
        Objsort3 (Boolean): The sorting criteria for the third objective.
        SearchRule (str): The search rule for the agent.
        Quantity (float): Represents the fraction of new demand that is assigned to the agent 
        MaturityThreshold (float): The maturity threshold of the agent. Only applies when using the maturity search rule. 
        SpendLimit (int, optional): Only applies when using the spend_limit search rule.  
        AgentType (str): The type of the agent. Defaults to 'New'. (In MUSE this parameter is called "Type")
        (InitialShare (dict): The initial share of the agent. Defaults to None.)
    Methods:
        method1(): Placeholder method. Define the functionality of method1 here.
        method2(): Placeholder method. Define the functionality of method2 here.
    """
    instances = []  # Class variable to track instances of the class

    def __init__(self
                 , Name
                 , AgentShare
                 , RegionName = "UK"
                 , Objective1 = "LCOE"
                 , Objective2 = ""
                 , Objective3 = ""
                 , ObjData1 = 1
                 , ObjData2 = ""
                 , ObjData3 = ""
                 , Objsort1 = True
                 , Objsort2 = False
                 , Objsort3 = False
                 , SearchRule = "all"
                 , Quantity = 1
                 , MaturityThreshold = 0
                 , DecisionMethod = "singleObj"
                 , SpendLimit = 99999999999
                 , AgentType = 'New'
                 ):
        # Initialize any attributes or variables here
        self.Name = Name
        self.AgentShare = AgentShare
        self.RegionName = RegionName #if RegionName else "UK"
        self.Objective1 = Objective1 #if Objective1 else "TRUE"
        self.Objective2 = Objective2 #if Objective2 else "FALSE"
        self.Objective3 = Objective3 #if Objective3 else "FALSE"
        self.ObjData1 = ObjData1
        self.ObjData2 = ObjData2
        self.ObjData3 = ObjData3
        self.Objsort1 = Objsort1
        self.Objsort2 = Objsort2
        self.Objsort3 = Objsort3
        self.SearchRule = SearchRule
        self.Quantity = Quantity
        self.MaturityThreshold = MaturityThreshold
        self.DecisionMethod = DecisionMethod
        self.SpendLimit = SpendLimit
        self.AgentType = AgentType
        # InitialShare is expected to be a dictionary with keys as agent's number and values are shares(0 to 1) of the agent in each of the technology
        #self.InitialShare = InitialShare if InitialShare is not None else {}

        # Add each instance to the list
        Agent.instances.append(self)  

   

    def method1(self):
        # Define the functionality of method1 here
        pass

    def method2(self):
        # Define the functionality of method2 here
        pass

    # Add more methods as needed

# %% [markdown]
# ### Create instances of the Agents (based on the demand share data calculated above)

# %%
# Iterate through each row of the DataFrame to create instances of Agent
for _, row in df.iterrows():
    # Extract the "Archetype" and "demand_share" values from the row
    name = row['Archetype']
    AgentShare = row['Archetype']
    demand_share = row['demand_share']
    
    # Create an instance of Agent and it will be automatically append it to the 'Agent.instances' list
    agent_instance = Agent(Name=name, AgentShare = AgentShare, Quantity=demand_share)
   

# Now, 'Agent.instances' is a list of Agent instances

# %%
# Use vars() or __dict__ to extract all attributes of each Agent instance
data = [vars(agent) for agent in Agent.instances]

# Create a new DataFrame from the list of dictionaries
agents_df = pd.DataFrame(data)

# Rename 'AgentType' to 'Type' as MUSE expects.
agents_df.rename(columns={'AgentType': 'Type'}, inplace=True) 

# Display the agents_df
agents_df
# Out:
#    Name AgentShare RegionName Objective1 Objective2 Objective3  ObjData1  \
# 0    A1         A1         UK       LCOE                               1
# 1    A2         A2         UK       LCOE                               1
# 2    A3         A3         UK       LCOE                               1
# 3    B4         B4         UK       LCOE                               1
# 4    B5         B5         UK       LCOE                               1
# 5    B6         B6         UK       LCOE                               1
# 6    C7         C7         UK       LCOE                               1
# 7    C8         C8         UK       LCOE                               1
# 8    C9         C9         UK       LCOE                               1
# 9   D10        D10         UK       LCOE                               1
# 10  D11        D11         UK       LCOE                               1
# 11  D12        D12         UK       LCOE                               1
# 12  E13        E13         UK       LCOE                               1
# 13  E14        E14         UK       LCOE                               1
# 14  F15        F15         UK       LCOE                               1
# 15  F16        F16         UK       LCOE                               1
# 16  G17        G17         UK       LCOE                               1
# 17  G18        G18         UK       LCOE                               1
# 18  H19        H19         UK       LCOE                               1
# 19  H20        H20         UK       LCOE                               1
# 20  I21        I21         UK       LCOE                               1
# 21  I22        I22         UK       LCOE                               1
# 22  J23        J23         UK       LCOE                               1
# 23  J24        J24         UK       LCOE                               1
#
#    ObjData2 ObjData3  Objsort1  Objsort2  Objsort3 SearchRule  Quantity  \
# 0                         True     False     False        all  0.032715
# 1                         True     False     False        all  0.029457
# 2                         True     False     False        all  0.033830
# 3                         True     False     False        all  0.011510
# 4                         True     False     False        all  0.015782
# 5                         True     False     False        all  0.032424
# 6                         True     False     False        all  0.040115
# 7                         True     False     False        all  0.013366
# 8                         True     False     False        all  0.040723
# 9                         True     False     False        all  0.042732
# 10                        True     False     False        all  0.026947
# 11                        True     False     False        all  0.047888
# 12                        True     False     False        all  0.052146
# 13                        True     False     False        all  0.044680
# 14                        True     False     False        all  0.076148
# 15                        True     False     False        all  0.010328
# 16                        True     False     False        all  0.065338
# 17                        True     False     False        all  0.058656
# 18                        True     False     False        all  0.054396
# 19                        True     False     False        all  0.035455
# 20                        True     False     False        all  0.046725
# 21                        True     False     False        all  0.055536
# 22                        True     False     False        all  0.049909
# 23                        True     False     False        all  0.083193
#
#     MaturityThreshold DecisionMethod   SpendLimit Type
# 0                   0      singleObj  99999999999  New
# 1                   0      singleObj  99999999999  New
# 2                   0      singleObj  99999999999  New
# 3                   0      singleObj  99999999999  New
# 4                   0      singleObj  99999999999  New
# 5                   0      singleObj  99999999999  New
# 6                   0      singleObj  99999999999  New
# 7                   0      singleObj  99999999999  New
# 8                   0      singleObj  99999999999  New
# 9                   0      singleObj  99999999999  New
# 10                  0      singleObj  99999999999  New
# 11                  0      singleObj  99999999999  New
# 12                  0      singleObj  99999999999  New
# 13                  0      singleObj  99999999999  New
# 14                  0      singleObj  99999999999  New
# 15                  0      singleObj  99999999999  New
# 16                  0      singleObj  99999999999  New
# 17                  0      singleObj  99999999999  New
# 18                  0      singleObj  99999999999  New
# 19                  0      singleObj  99999999999  New
# 20                  0      singleObj  99999999999  New
# 21                  0      singleObj  99999999999  New
# 22                  0      singleObj  99999999999  New
# 23                  0      singleObj  99999999999  New

# %%
# agents_df.to_csv(output_folder / "Agents.csv", index=False)
